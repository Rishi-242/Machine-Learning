# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/rgukt-basar/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
df=pd.read_csv("/home/rgukt-basar/E3-SEM2/ml LAB/WEEK-2/Car_sales.csv")
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#1. Read top five values
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
#2. Print dataframe info_data types of each column
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
#3. Print number of rows and columns
df.shape
# Out:
# (157, 15)

# %%
#4. Drop duplicate rows_if any
duplicate=df.drop_duplicates()
print(duplicate)
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#5. Print number of rows and columns after dropping duplicates
df.shape
# Out:
# (157, 15)

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#6. Print summary statistics for numerical variables
df.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
#7. Print number of missing values in each column
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
#8. Drop the column with most missing values
snrs=df.isnull().sum().idxmax()
print(snrs)
# Out:
# Manufacturer

# %%
#9. Drop the rows with categorical missing values
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
df = df.dropna(subset=categorical_cols)
print("After dropping rows with missing categorical values:")
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# After dropping rows with missing categorical values:
# Number of rows: 157
# Number of columns: 15

# %%
#10. Import the rows with numerical missing value
# Step 1: Identify numerical columns
numerical_cols = df.select_dtypes(include=['number']).columns

# Step 2: Get rows with missing values in any numerical column
rows_with_numerical_nan = df[df[numerical_cols].isnull().any(axis=1)]

# Display the result
print("Rows with missing numerical values:")
print(rows_with_numerical_nan)
# Out:
# Rows with missing numerical values:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
#11. Sort the data w.r.t price_find the details of the most and the least expensive cars
df_sorted = df.sort_values(by='Price in thousands')  # Make sure 'price' is the correct column name

# Step 2: Get the least expensive car (first row)
least_expensive = df_sorted.iloc[0]

# Step 3: Get the most expensive car (last row)
most_expensive = df_sorted.iloc[-1]

# Display the results
print("Least Expensive Car:\n", least_expensive)
print("\nMost Expensive Car:\n", most_expensive)
# Out:
# Least Expensive Car:
#  Manufacturer               Acura
# Model                  CL
# Sales in thousands                14.114
# 4-year resale value               18.225
# Vehicle type                   Passenger
# Price in thousands                     .
# Engine size                          3.2
# Horsepower                           225
# Wheelbase                          106.9
# Width                               70.6
# Length                               192
# Curb weight                         3.47
# Fuel capacity                       17.2
# Fuel efficiency                       26
# Latest Launch                   1-Apr-14
# Name: 2, dtype: object
#
# Most Expensive Car:
#  Manufacturer               Hyundai
# Model                  Accent
# Sales in thousands                41.184
# 4-year resale value                 5.86
# Vehicle type                   Passenger
# Price in thousands                 9.699
# Engine size                          1.5
# ...

# %%
#12. Write a function to find min and max values of any column
min_value=df['Price in thousands'].min()
max_value=df['Price in thousands'].max()
print(min_value)
print(max_value)
df
# Out:
# .
# 9.699
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#13. Call the above function to find min max of horsepower, length, fuel efficiency
df = pd.read_csv("car_sales.csv")
# Function to find min and max values of any column
def find_min_max(df,'Price in thousands'):
min_value = df['Price in thousands'].min()
max_value = df['Price in thousands'].max()
# Find the rows with the min and max values
min_row = df[df['Price in thousands'] == min_value]
max_row = df[df['Price in thousands'] == max_value]
return min_value, max_value, min_row, max_row
# Now call the function to find min and max for 'Horsepower'
hp_min, hp_max, hp_min_row, hp_max_row = find_min_max(df,"Horsepower")
# Print results
print("\nHorsepower - Min:", hp_min, "\n", hp_min_row)
print("\nHorsepower - Max:", hp_max, "\n", hp_max_row)
# Out:
#   Cell In[16], line 4
#     def find_min_max(df,'Price in thousands'):
#                         ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#14. Plot histogram of continuous numerical variable : price,sales,hoursepower,fuelefficiency.
import matplotlib.pyplot as plt

# Assuming you're using pandas DataFrame
import pandas as pd

# Example DataFrame
# Replace this with your actual DataFrame
df = pd.DataFrame({
    'Price of thousands': [20, 25, 30, 15, 22, 28],
    'sales': [200, 220, 250, 180, 210, 240],
    'hoursepower': [150, 160, 170, 140, 155, 165],
    'fuelefficiency': [25, 27, 23, 30, 28, 26]
})

# List of continuous variables to plot
columns = ['Price of thousands', 'sales', 'hoursepower', 'fuelefficiency']

# Plotting histograms
plt.figure(figsize=(12, 8))
for i, col in enumerate(columns):
    plt.subplot(2, 2, i + 1)
    plt.hist(df[col], bins=10, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
#15. Probability density distribution of continuous numerical variable-length
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Create dummy length data
df = pd.DataFrame({
    'length': np.random.normal(loc=150, scale=10, size=100)  # 100 values around 150
})

# Plot KDE
sns.kdeplot(df['length'], shade=True, color='purple')
plt.title('Probability Density Distribution of Length')
plt.xlabel('Length')
plt.ylabel('Density')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_7467/2152705204.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['length'], shade=True, color='purple')

# %%
#16. Count by category –group by manufacture
import matplotlib.pyplot as plt

# Make sure 'manufacturer_counts' is a DataFrame with 'manufacturer' and 'count' columns
manufacturer.sort_values('count', ascending=False, inplace=True)

plt.figure(figsize=(10, 6))
plt.bar(Manufacturer_counts['manufacturer'], Manufacturer['count'], color='teal')
plt.xticks(rotation=45, ha='right')
plt.title('Number of Entries by Manufacturer')
plt.xlabel('Manufacturer')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Make sure 'manufacturer_counts' is a DataFrame with 'manufacturer' and 'count' columns
# ----> 5 manufacturer.sort_values('count', ascending=False, inplace=True)
#       7 plt.figure(figsize=(10, 6))
#       8 plt.bar(Manufacturer_counts['manufacturer'], Manufacturer['count'], color='teal')
#
# NameError: name 'manufacturer' is not defined

# %%
#17. Select all numerical variables
numerical=df.select_dtypes(include=['number'])
print(numerical)

# %%
#18. Print correlation coefficient value of price and sales
import pandas as pd

# Sample DataFrame
data = {
    'price': [100, 150, 200, 250, 300],
    'sales': [500, 400, 300, 200, 100]
}

df = pd.DataFrame(data)

# Calculate and print correlation coefficient
correlation = df['price'].corr(df['sales'])
print("Correlation between price and sales:", correlation)
# Out:
# Correlation between price and sales: -0.9999999999999998
