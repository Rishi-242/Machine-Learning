# %% [markdown]
# Decision Tree
#
# Tiatnic Survival Dataset

# %%
#Import the Necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
#Load the data sets- train and test 
df=pd.read_csv("/home/rgukt-basar/E3-SEM2/ml LAB/WEEK-5/train_titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x=df[['PassengerId','Pclass','Name','Sex','Age','SibSp','Parch','Ticket','Fare','Cabin','Embarked']]
y=df['Survived']
print(x,y)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
#Look at top values of train data 
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Print the column names of train data
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
x_test,x_train,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
#Print the dimension of train and test data
print(x_train,y_train)
print(x_test,y_test)
# Out:
#      PassengerId  Pclass                                               Name  \
# 709          710       3  Moubarek, Master. Halim Gonios ("William George")
# 439          440       2             Kvillner, Mr. Johan Henrik Johannesson
# 840          841       3                        Alhomaki, Mr. Ilmari Rudolf
# 720          721       2                  Harper, Miss. Annie Jessie "Nina"
# 39            40       3                        Nicola-Yarred, Miss. Jamila
# ..           ...     ...                                                ...
# 821          822       3                                  Lulic, Mr. Nikola
# 633          634       1                      Parr, Mr. William Henry Marsh
# 456          457       1                          Millet, Mr. Francis Davis
# 500          501       3                                   Calic, Mr. Petar
# 430          431       1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
#
# ...

# %%
#Print the number of missing values in each column of train and test data
print(x_train.isnull().sum())
print(x_test.isnull().sum())
print(y_train.isnull().sum())
print(y_test.isnull().sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             53
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          203
# Embarked         1
# dtype: int64
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age            124
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          484
# Embarked         1
# dtype: int64
# 0
# 0

# %% [markdown]
# ## Data Visualization

# %%
#Barchart of Survived, Pclass, Sex, Embarked
df['Survived'].value_counts().plot(kind='bar')
plt.title('survived count')
plt.xlabel('Survived')
plt.ylabel('count')
plt.show()

df['Pclass'].value_count().plot(kind='bar')
plt.title('Pclass count')
plt.xlabel('Pclass')
plt.ylabel('count')
plt.show()

df['Sex'].value_counts().plot(kind='bar')
plt.title('SEx count')
plt.xlabel('Sex')
plt.ylabel('count');
plt.count()
df['Embarked'].value_counts().plot(kind='bar')
plt.title('Embarked count')
plt.xlabel('Embarked')
plt.ylabel('count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_9530/1958094283.py in ?()
#       4 plt.xlabel('Survived')
#       5 plt.ylabel('count')
#       6 plt.show()
#       7
# ----> 8 df['Pclass'].value_count().plot(kind='bar')
#       9 plt.title('Pclass count')
#      10 plt.xlabel('Pclass')
#      11 plt.ylabel('count')
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Histogram of Age, Parch, Fare
import matplotlib.pyplot as plt

# Assuming df is your DataFrame (e.g., Titanic dataset)

# Histogram of Age
plt.hist(df['Age'].dropna(), bins=20, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Histogram of Parch
plt.hist(df['Parch'], bins=range(df['Parch'].max()+2), color='lightgreen', edgecolor='black', align='left')
plt.title('Parch Distribution')
plt.xlabel('Parch (Parents/Children Aboard)')
plt.ylabel('Frequency')
plt.show()

# Histogram of Fare
plt.hist(df['Fare'], bins=30, color='salmon', edgecolor='black')
plt.title('Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %%
#Plot histogram of age for survived and did not survived 
import matplotlib.pyplot as plt

# Assuming `df` is your DataFrame (like Titanic dataset)

# Drop rows where Age is NaN
df_age = df.dropna(subset=['Age'])

# Plot
plt.hist(df_age[df_age['Survived'] == 1]['Age'], bins=20, alpha=0.6, label='Survived', color='green', edgecolor='black')
plt.hist(df_age[df_age['Survived'] == 0]['Age'], bins=20, alpha=0.6, label='Did Not Survive', color='red', edgecolor='black')

plt.title('Age Distribution: Survived vs Did Not Survive')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Count class and geder wise survival rate - plot with appropriate chart
#Age wise Distribution of Male and Female passengers
import pandas as pd
import matplotlib.pyplot as plt

# Group by Pclass and Sex, then calculate survival rate
survival_rate = df.groupby(['Pclass', 'Sex'])['Survived'].mean().unstack()

# Plot
survival_rate.plot(kind='bar', figsize=(8, 6), colormap='Set2')
plt.title('Survival Rate by Class and Gender')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.legend(title='Gender')
plt.grid(axis='y')
plt.ylim(0, 1)  # survival rate between 0 and 1
plt.show()

# Drop missing ages
df_age = df.dropna(subset=['Age'])

# Plot age distribution by gender
plt.hist(df_age[df_age['Sex'] == 'male']['Age'], bins=20, alpha=0.6, label='Male', color='blue', edgecolor='black')
plt.hist(df_age[df_age['Sex'] == 'female']['Age'], bins=20, alpha=0.6, label='Female', color='magenta', edgecolor='black')

plt.title('Age-wise Distribution of Male and Female Passengers')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Histogram of Age of the given data set(sample)
import matplotlib.pyplot as plt

# Drop missing age values if any
df_age = df['Age'].dropna()

# Plot the histogram
plt.hist(df_age, bins=20, color='skyblue', edgecolor='black')
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Handling Missing Values

# %%
#Replace the msiing values in Embarked column by 'S'
df['Embarked'].fillna('S',inplace=True)

# %%
#Impute the missing values in Fare column with median value
#df['Fare'].fillna(df['Fare'].median(),inplace=True)
df['Fare'].fillna(df['Fare'].median(), inplace=True)
# Out:
# /tmp/ipykernel_9530/3227805841.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fare'].fillna(df['Fare'].median(), inplace=True)

# %%
#Impute the Age column. It has too many missing values but it may be important. 
#We fill the missing values with numbers randomly drawn from distribution
#that has same mean and standard deviation as non missing Age data
import numpy as np

# Get the mean and std of non-missing Age values
age_mean = df['Age'].mean()
age_std = df['Age'].std()

# Count how many values are missing
num_missing = df['Age'].isnull().sum()

# Generate random ages from the same distribution
random_ages = np.random.normal(loc=age_mean, scale=age_std, size=num_missing)

# Set a random seed (optional, for reproducibility)
np.random.seed(42)

# Fill the missing Age values with these random values
df.loc[df['Age'].isnull(), 'Age'] = random_ages

# %% [markdown]
# ## Feature Engineering - Creating new features

# %%
# Create and add a new feature FamilySize as a combination of SibSp and Parch
#FamilySize = Parch + SibSp + 1
# Create the FamilySize feature
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# %%
# Create new feature IsAlone from FamilySize
#If FamilySize == 1 then IsAlone = True else IsAlone = False
df['IsAlone'] = (df['FamilySize'] == 1).astype(int)

# %% [markdown]
# ## Create a new attribute Has_cabin using the attribue Cabin.
# if Cabin == NaN the Has_cabin = False else Has_cabin = True
# # Create Has_Cabin feature
# df['Has_Cabin'] = df['Cabin'].notnull()

# %%
#Drop the columns which may not be useful in prediction of survival
#Drop PassengerId, Name, Ticket, and Cabin
df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %% [markdown]
# ## Model Building

# %%
df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  30.690197      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#      FamilySize  IsAlone
# 0             2        0
# 1             2        0
# ...

# %%
#Prepare X and y
# Prepare X and y
X = df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'FamilySize', 'IsAlone']]  # Columns for prediction
y = df['Survived']  # Target variable

# Print X and y to check
print(X.head(), y.head())  # Display the first few rows of X and y
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked  FamilySize  IsAlone
# 0       3    male  22.0      1      0   7.2500        S           2        0
# 1       1  female  38.0      1      0  71.2833        C           2        0
# 2       3  female  26.0      0      0   7.9250        S           1        1
# 3       1  female  35.0      1      0  53.1000        S           2        0
# 4       3    male  35.0      0      0   8.0500        S           1        1 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
# Label encoding of categorical features
from sklearn.preprocessing import LabelEncoder

# Create a label encoder object
label_encoder = LabelEncoder()

# Encode categorical features
X['Sex'] = label_encoder.fit_transform(X['Sex'])  # 'male' -> 1, 'female' -> 0
X['Embarked'] = label_encoder.fit_transform(X['Embarked'].astype(str))  # 'S', 'C', 'Q' -> numerical values

# Print the transformed data
print(X[['Sex', 'Embarked']].head())
# Out:
#    Sex  Embarked
# 0    1         2
# 1    0         0
# 2    0         2
# 3    0         2
# 4    1         2
# /tmp/ipykernel_9530/1527594607.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Sex'] = label_encoder.fit_transform(X['Sex'])  # 'male' -> 1, 'female' -> 0
# /tmp/ipykernel_9530/1527594607.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Embarked'] = label_encoder.fit_transform(X['Embarked'].astype(str))  # 'S', 'C', 'Q' -> numerical values

# %%
# concat df_categorical with original df
# Assuming df_categorical contains the encoded categorical columns 'Sex' and 'Embarked'

# Concatenate the original dataframe with the encoded categorical columns
df = pd.concat([df, X[['Sex', 'Embarked']]], axis=1)

# Print the first few rows to verify
print(df.head())
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare  Embarked  \
# 0         0       3    male  22.0      1      0   7.2500         S
# 1         1       1  female  38.0      1      0  71.2833         C
# 2         1       3  female  26.0      0      0   7.9250         S
# 3         1       1  female  35.0      1      0  53.1000         S
# 4         0       3    male  35.0      0      0   8.0500         S
#
#    FamilySize  IsAlone  Sex  Embarked
# 0           2        0    1         2
# 1           2        0    0         0
# 2           1        1    0         2
# 3           2        0    0         2
# 4           1        1    1         2

# %%
#Do a pairplot of all features
import seaborn as sns

# Select the columns you want to plot
# If you have too many columns, you may want to limit it to a subset of the most important ones
sns.pairplot(df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'FamilySize', 'IsAlone', 'Survived']])

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 6
#       2 import seaborn as sns
#       4 # Select the columns you want to plot
#       5 # If you have too many columns, you may want to limit it to a subset of the most important ones
# ----> 6 sns.pairplot(df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'FamilySize', 'IsAlone', 'Survived']])
#       8 # Display the plot
#       9 plt.show()
#
# File ~/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:2119, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117 # Set up the PairGrid
#    2118 grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119 grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
# ...

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation
x_train,x_test,y_train,y_test=train_test_split(x,test_size=0.9,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 3
#       1 # Splitting the data into train and validation set - 90% train 10% validation
#       2 #X_train, X_test, y_train, y_validation
# ----> 3 x_train,x_test,y_train,y_test=train_test_split(x,test_size=0.9,random_state=42)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
# Create the model
# Fitting the decision tree with default hyperparameters
# Importing decision tree classifier from sklearn library

# %%
#Print the tree

# Importing required packages for visualization

# %%
# plotting tree with max_depth=3

# %% [markdown]
# <img src="tree2.png">

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

# Printing classification report

# %%
# Printing confusion matrix and accuracy
