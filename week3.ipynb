# %%
#. Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#1. Import dataset and display first 5 rows
df=pd.read_csv("/home/rgukt-basar/E3-SEM2/ml LAB/WEEK-3/tvmarketing.csv")

# %%
#2. Check column data types
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
 #3. Check the shape of the Data Frame (rows, columns)
df.shape
# Out:
# (200, 2)

# %%
##4. Look at summary statistics
df.describe()
# Out:
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
#5. Visualize the relationship between the features and the dependent variable using scatterplots
##6. Prepare X (feature variables) and y (response variables
x=df['TV']
y=df['Sales']
plt.scatter(x,y)
plt.show()

# %%
#7. Split Data into Training and Testing Sets (70%-Train 30%-Test) - X_train, y_train, X_test, y_test
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=3)

# %%
#8. Print the shape of train data and test data
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# 77     120.5
# 73     129.4
# 71     109.8
# 78       5.4
# 42     293.6
#        ...
# 0      230.1
# 184    253.8
# 131    265.2
# 152    197.6
# 106     25.0
# Name: TV, Length: 140, dtype: float64
# 40     202.5
# 51     100.4
# 139    184.9
# 197    177.0
# 170     50.0
# 82      75.3
# 183    287.6
# 46      89.7
# 70     199.1
# 100    222.4
# 179    165.6
# 83      68.4
# 25     262.9
# 190     39.5
# 159    131.7
# 173    168.4
# 95     163.3
# 3      151.5
# 41     177.0
# 58     210.8
# 14     204.1
# 143    104.6
# 12      23.8
# 6       57.5
# 182     56.2
# 161     85.7
# 128    220.3
# 122    224.0
# 101    296.4
# 86      76.3
# 64     131.1
# 47     239.9
# 158     11.7
# 34      95.7
# 38      43.1
# 196     94.2
# 4      180.8
# 72      26.8
# 67     139.3
# 145    140.3
# 156     93.9
# 115     75.1
# 155      4.1
# 15     195.4
# 61     261.3
# 175    276.9
# 120    141.3
# 130      0.7
# 23     228.3
# 153    171.3
# 31     112.9
# 103    187.9
# 89     109.8
# 132      8.4
# 109    255.4
# 126      7.8
# 17     281.4
# 30     292.9
# 178    276.7
# 162    188.4
# Name: TV, dtype: float64
# 77     14.2
# 73     11.0
# 71     12.4
# 78      5.3
# 42     20.7
#        ...
# 0      22.1
# 184    17.6
# 131    12.7
# 152    16.6
# 106     7.2
# Name: Sales, Length: 140, dtype: float64
# 40     16.6
# 51     10.7
# 139    20.7
# 197    12.8
# 170     8.4
# 82     11.3
# 183    26.2
# 46     10.6
# 70     18.3
# 100    11.7
# 179    12.6
# 83     13.6
# 25     12.0
# 190    10.8
# 159    12.9
# 173    11.7
# 95     16.9
# 3      18.5
# 41     17.1
# 58     23.8
# 14     19.0
# 143    10.4
# 12      9.2
# 6      11.8
# 182     8.7
# 161    13.3
# 128    24.7
# 122    11.6
# 101    23.8
# 86     12.0
# 64     18.0
# 47     23.2
# 158     7.3
# 34      9.5
# 38     10.1
# 196     9.7
# 4      12.9
# 72      8.8
# 67     13.4
# 145    10.3
# 156    15.3
# 115    12.6
# 155     3.2
# 15     22.4
# 61     24.2
# 175    27.0
# 120    15.5
# 130     1.6
# 23     15.5
# 153    19.0
# 31     11.9
# 103    14.7
# 89     16.7
# 132     5.7
# 109    19.8
# 126     6.6
# 17     24.4
# 30     21.4
# 178    11.8
# 162    14.9
# Name: Sales, dtype: float64

# %%
#9. Perform Linear Regression (ontrain data) with using any library and print the coefficients values
model=LinearRegression()
print(model)
# Out:
# LinearRegression()

# %%
#9. Perform Linear Regression (on train data) without using any library and print the coefficients values
import numpy as np
X=x_train.values.reshape(-1)
Y=y_train.values.reshape(-1)
n=len(X)
sum_xy=np.sum(X*Y)
sum_x=np.sum(X)
sum_y=np.sum(Y)
sum_x2=np.sum(x**2)
m=(n*sum_xy-sum_x*sum_y)/(n*sum_x2-sum_x**2)#y=mx+c c=y-mx
c=(sum_y-m*sum_x)/n
print(c)
# Out:
# 11.317050380087531

# %%
#9. Perform Linear Regression (on train data) without using any library and print the coefficients values
print(m)
print(c)
# Out:
# 0.01699096495380881
# 11.317050380087531

# %%
#10.Create the model using the calculated coefficients and make predictions on the testing set
#y=mx+C
y_predict=m*x_test+c
print(y_predict)
# Out:
# 40     14.757721
# 51     13.022943
# 139    14.458680
# 197    14.324451
# 170    12.166599
# 82     12.596470
# 183    16.203652
# 46     12.841140
# 70     14.699952
# 100    15.095841
# 179    14.130754
# 83     12.479232
# 25     15.783975
# 190    11.988193
# 159    13.554760
# 173    14.178329
# 95     14.091675
# 3      13.891182
# 41     14.324451
# 58     14.898746
# 14     14.784906
# 143    13.094305
# 12     11.721435
# 6      12.294031
# 182    12.271943
# 161    12.773176
# 128    15.060160
# 122    15.123027
# 101    16.353172
# 86     12.613461
# 64     13.544566
# 47     15.393183
# 158    11.515845
# 34     12.943086
# 38     12.049361
# 196    12.917599
# 4      14.389017
# 72     11.772408
# 67     13.683892
# 145    13.700883
# 156    12.912502
# 115    12.593072
# 155    11.386713
# 15     14.637085
# 61     15.756790
# 175    16.021849
# 120    13.717874
# 130    11.328944
# 23     15.196088
# 153    14.227603
# 31     13.235330
# 103    14.509653
# 89     13.182658
# 132    11.459774
# 109    15.656543
# 126    11.449580
# 17     16.098308
# 30     16.293704
# 178    16.018450
# 162    14.518148
# Name: TV, dtype: float64

# %%
#11.Perform Linear Regression using library(sklearn)
from sklearn.model_selection import train_test_split
x_train=x_train.values.reshape(-1, 1)
x_test=x_test.values.reshape(-1, 1)
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
##12.Print the intercept and coefficients
model.intercept_
# Out:
# np.float64(7.18668513031629)

# %%
##14.Plot train data and the model
plt.scatter(x_train,y_train)
plt.plot(x_train,model.predict(x_train),color="red")

# %% [markdown]
# model.coef_

# %%
#15.Plot test data and the model
plt.scatter(x_test,y_test)
plt.plot(x_test,model.predict(x_test), color="red")

# %%
#12.Print the intercept and coefficients
print(m)
print(c)
# Out:
# 0.01699096495380881
# 11.317050380087531

# %%
#13.Make predictions on the testing set - y_pred
y_predict=model.predict(x_train)
print(y_predict)
# Out:
# [[14.2 11.  12.4  5.3 20.7 19.6  5.9  9.7 13.2 17.   7.2 14.6 14.8 12.2
#    7.  17.1 14.5  9.7 11.4 19.4  4.8 21.2 15.9 19.2 15.9 18.  12.9 13.2
#   11.9  5.6 10.5 17.3 14.4 16.  10.8 14.  10.9 19.6 11.6 14.9 12.8  9.3
#   11.4 10.6 25.4 12.5 14.6  5.3  8.5 18.9  6.9 19.2 14.1  8.6 21.7 17.4
#   23.7 12.9 20.2 21.8  9.5 10.6 20.8  9.6 10.5 21.5 22.6  5.5 10.3 17.3
#    7.3 18.4 11.5 25.4 11.7 22.6  9.9 14.8 11.7  8.7 11.6 11.8 17.2 19.7
#   15.6  9.4 15.2 10.4 15.9 11.9 12.2 11.3  7.6 20.2 15.9 18.9  8.8  6.7
#    9.7 11.5 18.  14.7 11.  15.2 17.4 13.2 15.7 25.5 13.4 10.1 15.5 13.4
#   20.7 22.3 11.2  9.7  8.1  9.3  9.5 16.1 12.3 15.  20.1 12.2 22.2  7.6
#   10.9  8.   6.6 10.1  9.6 15.   8.7 25.4 12.5 22.1 17.6 12.7 16.6  7.2]]

# %%
#16.Print Mean Squared Error and R Squared Value
